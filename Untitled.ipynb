# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import mean_squared_error

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df_riders = pd.read_csv("data/Riders.csv")
df_train = pd.read_csv("data/Train.csv")

df = df_riders.merge(df_train, how='inner', on='Rider Id')
df.columns = df.columns.str.lower().str.replace(' ', '_')
del df['arrival_at_destination_-_time']
df.shape
# Out:
# (21201, 32)

# %%
df.head().T
# Out:
#                                                         0               1  \
# rider_id                                     Rider_Id_396    Rider_Id_396
# no_of_orders                                         2946            2946
# age                                                  2298            2298
# average_rating                                       14.0            14.0
# no_of_ratings                                        1159            1159
# order_no                                   Order_No_19506  Order_No_14309
# user_id                                      User_Id_2746    User_Id_1792
# vehicle_type                                         Bike            Bike
# platform_type                                           1               3
# personal_or_business                             Personal        Business
# placement_-_day_of_month                                1              12
# placement_-_weekday_(mo_=_1)                            2               5
# placement_-_time                              10:41:49 AM     10:38:29 AM
# confirmation_-_day_of_month                             1              12
# confirmation_-_weekday_(mo_=_1)                         2               5
# confirmation_-_time                           10:43:49 AM     10:39:10 AM
# arrival_at_pickup_-_day_of_month                        1              12
# arrival_at_pickup_-_weekday_(mo_=_1)                    2               5
# arrival_at_pickup_-_time                      11:05:49 AM     10:54:14 AM
# pickup_-_day_of_month                                   1              12
# pickup_-_weekday_(mo_=_1)                               2               5
# pickup_-_time                                 11:13:22 AM     10:59:24 AM
# arrival_at_destination_-_day_of_month                   1              12
# arrival_at_destination_-_weekday_(mo_=_1)               2               5
# distance_(km)                                           4               3
# temperature                                          21.7            24.4
# precipitation_in_millimeters                          NaN             NaN
# pickup_lat                                       -1.27845       -1.280912
# pickup_long                                     36.798173       36.785252
# destination_lat                                 -1.278948       -1.273431
# destination_long                                36.812236       36.786378
# time_from_pickup_to_arrival                           491             482
#
#                                                        2             3  \
# rider_id                                    Rider_Id_479  Rider_Id_479
# no_of_orders                                         360           360
# age                                                  951           951
# average_rating                                      13.5          13.5
# no_of_ratings                                        176           176
# order_no                                   Order_No_5471  Order_No_515
# user_id                                     User_Id_2162  User_Id_1363
# vehicle_type                                        Bike          Bike
# platform_type                                          3             3
# personal_or_business                            Business      Business
# placement_-_day_of_month                               7             3
# placement_-_weekday_(mo_=_1)                           1             4
# placement_-_time                              1:38:41 PM    3:02:30 PM
# confirmation_-_day_of_month                            7             3
# confirmation_-_weekday_(mo_=_1)                        1             4
# confirmation_-_time                           1:44:38 PM    3:11:55 PM
# arrival_at_pickup_-_day_of_month                       7             3
# arrival_at_pickup_-_weekday_(mo_=_1)                   1             4
# arrival_at_pickup_-_time                      2:08:57 PM    3:20:12 PM
# pickup_-_day_of_month                                  7             3
# pickup_-_weekday_(mo_=_1)                              1             4
# pickup_-_time                                 2:23:06 PM    3:24:26 PM
# arrival_at_destination_-_day_of_month                  7             3
# arrival_at_destination_-_weekday_(mo_=_1)              1             4
# distance_(km)                                         12             5
# temperature                                         20.3          24.8
# precipitation_in_millimeters                         NaN           NaN
# pickup_lat                                     -1.256624     -1.300406
# pickup_long                                    36.870685     36.829741
# destination_lat                                -1.261589     -1.307787
# destination_long                               36.792873     36.844321
# time_from_pickup_to_arrival                         1967           707
#
#                                                         4
# rider_id                                     Rider_Id_479
# no_of_orders                                          360
# age                                                   951
# average_rating                                       13.5
# no_of_ratings                                         176
# order_no                                   Order_No_12379
# user_id                                      User_Id_2622
# vehicle_type                                         Bike
# platform_type                                           2
# personal_or_business                             Personal
# placement_-_day_of_month                                2
# placement_-_weekday_(mo_=_1)                            3
# placement_-_time                              10:38:28 AM
# confirmation_-_day_of_month                             2
# confirmation_-_weekday_(mo_=_1)                         3
# confirmation_-_time                           10:45:48 AM
# arrival_at_pickup_-_day_of_month                        2
# arrival_at_pickup_-_weekday_(mo_=_1)                    3
# arrival_at_pickup_-_time                      11:04:07 AM
# pickup_-_day_of_month                                   2
# pickup_-_weekday_(mo_=_1)                               3
# pickup_-_time                                 11:09:49 AM
# arrival_at_destination_-_day_of_month                   2
# arrival_at_destination_-_weekday_(mo_=_1)               3
# distance_(km)                                           6
# temperature                                          21.8
# precipitation_in_millimeters                          NaN
# pickup_lat                                      -1.292206
# pickup_long                                     36.800284
# destination_lat                                 -1.300921
# destination_long                                36.828195
# time_from_pickup_to_arrival                          1543

# %% [markdown]
# # modeling

# %%
def prepare_model(df):
    #Feature engineering
    df['placement_-_time_hour'] = pd.to_datetime(df['placement_-_time']).dt.hour
    df['placement_-_time_minute'] = pd.to_datetime(df['placement_-_time']).dt.minute
    del df['placement_-_time']

    df['confirmation_-_time_hour'] = pd.to_datetime(df['confirmation_-_time']).dt.hour
    df['confirmation_-_time_minute'] = pd.to_datetime(df['confirmation_-_time']).dt.minute
    del df['confirmation_-_time']

    df['arrival_at_pickup_-_time_hour'] = pd.to_datetime(df['arrival_at_pickup_-_time']).dt.hour
    df['arrival_at_pickup_-_time_minute'] = pd.to_datetime(df['arrival_at_pickup_-_time']).dt.minute
    del df['arrival_at_pickup_-_time']


    df['pickup_-_time_hour'] = pd.to_datetime(df['pickup_-_time']).dt.hour
    df['pickup_-_time_minute'] = pd.to_datetime(df['pickup_-_time']).dt.minute
    del df['pickup_-_time']


    #df['arrival_at_destination_-_time_hour'] = pd.to_datetime(df['arrival_at_destination_-_time']).dt.hour
    #df['arrival_at_destination_-_time_minute'] = pd.to_datetime(df['arrival_at_destination_-_time']).dt.minute
    #del df['arrival_at_destination_-_time']
    
    
    #replace mising values
    df['temperature'] = df['temperature'].fillna(0)
    df['precipitation_in_millimeters'] = df['precipitation_in_millimeters'].fillna(0)
    
    return df

# %%
def apply_log_transform(y):
    return np.log1p(y)

apply_log_transform(2000)
# Out:
# 7.601402334583733

# %%
df = prepare_model(df)
df.sample(3).T
# Out:
#                                                      5424            2557  \
# rider_id                                     Rider_Id_726    Rider_Id_268
# no_of_orders                                         1337            1714
# age                                                   875            1980
# average_rating                                       14.2            13.2
# no_of_ratings                                         243             357
# order_no                                   Order_No_24260  Order_No_17171
# user_id                                      User_Id_1205    User_Id_1342
# vehicle_type                                         Bike            Bike
# platform_type                                           3               3
# personal_or_business                             Business        Business
# placement_-_day_of_month                                1               6
# placement_-_weekday_(mo_=_1)                            4               2
# confirmation_-_day_of_month                             1               6
# confirmation_-_weekday_(mo_=_1)                         4               2
# arrival_at_pickup_-_day_of_month                        1               6
# arrival_at_pickup_-_weekday_(mo_=_1)                    4               2
# pickup_-_day_of_month                                   1               6
# pickup_-_weekday_(mo_=_1)                               4               2
# arrival_at_destination_-_day_of_month                   1               6
# arrival_at_destination_-_weekday_(mo_=_1)               4               2
# distance_(km)                                           8               9
# temperature                                           0.0            24.9
# precipitation_in_millimeters                          0.0             0.0
# pickup_lat                                      -1.257309       -1.290894
# pickup_long                                     36.806008       36.822971
# destination_lat                                 -1.283965       -1.302583
# destination_long                                 36.78917       36.767081
# time_from_pickup_to_arrival                          2218            3103
# placement_-_time_hour                                  10              11
# placement_-_time_minute                                40              44
# confirmation_-_time_hour                               10              11
# confirmation_-_time_minute                             40              50
# arrival_at_pickup_-_time_hour                          10              11
# arrival_at_pickup_-_time_minute                        44              50
# pickup_-_time_hour                                     10              12
# pickup_-_time_minute                                   47              33
#
#                                                      5864
# rider_id                                     Rider_Id_735
# no_of_orders                                          407
# age                                                   875
# average_rating                                       14.1
# no_of_ratings                                         108
# order_no                                   Order_No_23471
# user_id                                      User_Id_2350
# vehicle_type                                         Bike
# platform_type                                           1
# personal_or_business                             Personal
# placement_-_day_of_month                               24
# placement_-_weekday_(mo_=_1)                            4
# confirmation_-_day_of_month                            24
# confirmation_-_weekday_(mo_=_1)                         4
# arrival_at_pickup_-_day_of_month                       24
# arrival_at_pickup_-_weekday_(mo_=_1)                    4
# pickup_-_day_of_month                                  24
# pickup_-_weekday_(mo_=_1)                               4
# arrival_at_destination_-_day_of_month                  24
# arrival_at_destination_-_weekday_(mo_=_1)               4
# distance_(km)                                           9
# temperature                                          21.4
# precipitation_in_millimeters                          0.0
# pickup_lat                                      -1.311471
# pickup_long                                     36.808871
# destination_lat                                 -1.274511
# destination_long                                 36.79745
# time_from_pickup_to_arrival                           936
# placement_-_time_hour                                  10
# placement_-_time_minute                                25
# confirmation_-_time_hour                               10
# confirmation_-_time_minute                             27
# arrival_at_pickup_-_time_hour                          10
# arrival_at_pickup_-_time_minute                        33
# pickup_-_time_hour                                     10
# pickup_-_time_minute                                   39

# %%
df.time_from_pickup_to_arrival = df['time_from_pickup_to_arrival'].apply(apply_log_transform)

# %%
df_train_full, df_test = train_test_split(df, test_size=0.2, random_state=1)
df_train, df_val = train_test_split(df_train_full, test_size=0.25, random_state=1)

df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)


y_train = df_train.time_from_pickup_to_arrival.values
y_val = df_val.time_from_pickup_to_arrival.values
y_test = df_test.time_from_pickup_to_arrival.values


del df_train['time_from_pickup_to_arrival']
del df_val['time_from_pickup_to_arrival']
del df_test['time_from_pickup_to_arrival']


print(df_train.shape[0], df_val.shape[0], df_test.shape[0] )
# Out:
# 12720 4240 4241

# %%
#Use DictVectorizer(sparse=True) to turn the dataframes into matrices.
train_dict = df_train.to_dict(orient='records')

dv = DictVectorizer(sparse=False)
X_train = dv.fit_transform(train_dict)

val_dict = df_val.to_dict(orient='records')
X_val = dv.transform(val_dict)

# %% [markdown]
# # Training and Evaluate model

# %%
from sklearn.tree import DecisionTreeRegressor,export_text

# %%
dt = DecisionTreeRegressor(max_depth=1)
dt.fit(X_train,y_train)

y_pred = dt.predict(X_val)
rmse = mean_squared_error(y_val,y_pred,squared=False)
print(round(rmse,3))
# Out:
# 1.122

# %% [markdown]
# # Evaluate model on Test set

# %%
df_riders = pd.read_csv("data/Riders.csv")
df_test = pd.read_csv("data/Test.csv")

df_test = df_riders.merge(df_test, how='inner', on='Rider Id')
df_test.columns = df_test.columns.str.lower().str.replace(' ', '_')
df_test.shape
# Out:
# (7068, 29)

# %%
def convert_to_original(x):
    return int(np.exp(x))

# %%
df_test.sample(3).T
# Out:
#                                                2479           3632  \
# rider_id                               Rider_Id_354   Rider_Id_622
# no_of_orders                                   1130           1465
# age                                            1715            719
# average_rating                                 13.3           14.3
# no_of_ratings                                   303            130
# order_no                              Order_No_4333  Order_No_8729
# user_id                                User_Id_3201   User_Id_1464
# vehicle_type                                   Bike           Bike
# platform_type                                     3              2
# personal_or_business                       Business       Personal
# placement_-_day_of_month                         28             28
# placement_-_weekday_(mo_=_1)                      4              5
# placement_-_time                         9:25:42 AM    12:57:52 PM
# confirmation_-_day_of_month                      28             28
# confirmation_-_weekday_(mo_=_1)                   4              5
# confirmation_-_time                      9:26:26 AM    12:59:27 PM
# arrival_at_pickup_-_day_of_month                 28             28
# arrival_at_pickup_-_weekday_(mo_=_1)              4              5
# arrival_at_pickup_-_time                 9:39:00 AM     1:22:59 PM
# pickup_-_day_of_month                            28             28
# pickup_-_weekday_(mo_=_1)                         4              5
# pickup_-_time                            9:55:34 AM     1:30:51 PM
# distance_(km)                                     1             10
# temperature                                    22.3           25.3
# precipitation_in_millimeters                    NaN            NaN
# pickup_lat                                -1.256133      -1.274538
# pickup_long                               36.799046       36.82958
# destination_lat                           -1.258414      -1.293888
# destination_long                            36.8048      36.777408
#
#                                                 1698
# rider_id                                Rider_Id_353
# no_of_orders                                    2173
# age                                             1157
# average_rating                                  14.5
# no_of_ratings                                    683
# order_no                              Order_No_10040
# user_id                                 User_Id_2763
# vehicle_type                                    Bike
# platform_type                                      3
# personal_or_business                        Business
# placement_-_day_of_month                          30
# placement_-_weekday_(mo_=_1)                       3
# placement_-_time                          2:53:32 PM
# confirmation_-_day_of_month                       30
# confirmation_-_weekday_(mo_=_1)                    3
# confirmation_-_time                       2:53:50 PM
# arrival_at_pickup_-_day_of_month                  30
# arrival_at_pickup_-_weekday_(mo_=_1)               3
# arrival_at_pickup_-_time                  3:03:14 PM
# pickup_-_day_of_month                             30
# pickup_-_weekday_(mo_=_1)                          3
# pickup_-_time                             3:05:41 PM
# distance_(km)                                      2
# temperature                                     28.9
# precipitation_in_millimeters                     NaN
# pickup_lat                                 -1.257147
# pickup_long                                36.795063
# destination_lat                            -1.268661
# destination_long                           36.803159

# %%
df_test = prepare_model(df_test)
df_test.sample(3).T
# Out:
#                                                6739            3913  \
# rider_id                               Rider_Id_438    Rider_Id_383
# no_of_orders                                    557            2412
# age                                             239             787
# average_rating                                 14.6            14.3
# no_of_ratings                                    55             309
# order_no                              Order_No_7583  Order_No_17134
# user_id                                 User_Id_733    User_Id_3470
# vehicle_type                                   Bike            Bike
# platform_type                                     3               3
# personal_or_business                       Business        Business
# placement_-_day_of_month                         17               3
# placement_-_weekday_(mo_=_1)                      3               4
# confirmation_-_day_of_month                      17               3
# confirmation_-_weekday_(mo_=_1)                   3               4
# arrival_at_pickup_-_day_of_month                 17               3
# arrival_at_pickup_-_weekday_(mo_=_1)              3               4
# pickup_-_day_of_month                            17               3
# pickup_-_weekday_(mo_=_1)                         3               4
# distance_(km)                                    12              10
# temperature                                     0.0            26.1
# precipitation_in_millimeters                    0.0             0.0
# pickup_lat                                -1.255189       -1.225322
# pickup_long                               36.782203        36.80855
# destination_lat                           -1.325747        -1.28878
# destination_long                          36.859207       36.816831
# placement_-_time_hour                            14              12
# placement_-_time_minute                          35              37
# confirmation_-_time_hour                         14              13
# confirmation_-_time_minute                       35               7
# arrival_at_pickup_-_time_hour                    14              13
# arrival_at_pickup_-_time_minute                  37              33
# pickup_-_time_hour                               14              14
# pickup_-_time_minute                             40               7
#
#                                                 6756
# rider_id                                Rider_Id_438
# no_of_orders                                     557
# age                                              239
# average_rating                                  14.6
# no_of_ratings                                     55
# order_no                              Order_No_24993
# user_id                                 User_Id_2344
# vehicle_type                                    Bike
# platform_type                                      3
# personal_or_business                        Business
# placement_-_day_of_month                          30
# placement_-_weekday_(mo_=_1)                       2
# confirmation_-_day_of_month                       30
# confirmation_-_weekday_(mo_=_1)                    2
# arrival_at_pickup_-_day_of_month                  30
# arrival_at_pickup_-_weekday_(mo_=_1)               2
# pickup_-_day_of_month                             30
# pickup_-_weekday_(mo_=_1)                          2
# distance_(km)                                      7
# temperature                                      0.0
# precipitation_in_millimeters                     0.0
# pickup_lat                                 -1.286937
# pickup_long                                36.824674
# destination_lat                            -1.256045
# destination_long                           36.780087
# placement_-_time_hour                             12
# placement_-_time_minute                           20
# confirmation_-_time_hour                          12
# confirmation_-_time_minute                        41
# arrival_at_pickup_-_time_hour                     12
# arrival_at_pickup_-_time_minute                   51
# pickup_-_time_hour                                12
# pickup_-_time_minute                              55

# %%
test_dict = df_test.to_dict(orient='records')
X_test = dv.transform(test_dict)

# %%
y_pred_test = dt.predict(X_test)

# %%
df_sub=df_test[['order_no']]
df_sub['Time from Pickup to Arrival'] = y_pred_test
df_sub['Time from Pickup to Arrival']=df_sub['Time from Pickup to Arrival'].apply(convert_to_original)
df_sub['order_no'] = df_sub['order_no'].str.strip()
df_sub.shape
# Out:
# /tmp/ipykernel_53548/4090796092.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['Time from Pickup to Arrival'] = y_pred_test
# /tmp/ipykernel_53548/4090796092.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['Time from Pickup to Arrival']=df_sub['Time from Pickup to Arrival'].apply(convert_to_original)
# /tmp/ipykernel_53548/4090796092.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sub['order_no'] = df_sub['order_no'].str.strip()
# (7068, 2)

# %%
df_sub.sample(5)
# Out:
#             order_no  Time from Pickup to Arrival
# 2356   Order_No_1188                         1462
# 6875   Order_No_2824                         1462
# 2118  Order_No_20284                         1462
# 4819  Order_No_23221                         1462
# 5104  Order_No_19052                          564

# %%
import time

ts = int(time.time())
df_sub.to_csv('./submissions/{}.csv'.format(str(ts)),index=False)
